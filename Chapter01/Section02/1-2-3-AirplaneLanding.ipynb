# %% [markdown]
# # Atterraggio di un aereo
# ## Accelerazione. Distanza di arresto
#
# Un aereo in fase di atterraggio su una portaerei tocca la pista alla velocità di $ 234 km/h$ e si ferma completamente in 2 secondi a causa di un cavo di arresto a cui si aggancia. Supponendo che il moto sia un moto uniformemente accelerato, calcolare:
# * a) l'accelerazione
# * b) la distanza percorsa sulla pista durante la fase di atterraggio.
#
# &nbsp;
#
# ![](https://i2.wp.com/www.aviation-report.com/wp-content/uploads/2020/03/F18-Super-Hornet-sulla-portaerei-francese-De-Gaulle.jpg?resize=750%2C400&ssl=1)
#
# ![](https://marinecue.it/wp-content/uploads/2018/06/Cavo-di-arresto-portaerei.jpg)

# %% [markdown]
# See also the following video from minute 0:35 to 0:42

# %%
from IPython.display import YouTubeVideo
id = 'KNDey1HOOVw'
YouTubeVideo(id=id,width=600,height=300)

# %% [markdown]
# &nbsp;
#
# ![](https://qph.fs.quoracdn.net/main-qimg-3ef93e0a73fd2f8e7919b8664bb79c25)

# %% [markdown]
# &nbsp;
#
# ![](https://qph.fs.quoracdn.net/main-qimg-74da0bc602a1df0f69b668be189065ab)

# %% [markdown]
# &nbsp;
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/FA-18_Trap.jpg/1280px-FA-18_Trap.jpg)

# %% [markdown]
# ## Discussione del problema
#
# ### Calcolo dell'accelerazione
# L'accelerazione è definita come rapporto fra la variazione di velocità $\Delta v$ e la durata dell'intervallo di tempo $\Delta t$ in cui essa avviene.
#     $$ a = \dfrac{\Delta v}{\Delta t} = \dfrac{v_f - v_i}{t_f - t_i} $$
# Per descrivere il moto dell'aereo lungo la pista di atterraggio utilizziamo un asse $x$ parallelo alla pista ed orientato nel senso di marcia dell'aereo. Notiamo che la velocità finale è nulla e la velocità iniziale è positiva, quindi la variazione di velocità è negativa e l'accelerazione sarà negativa.
# $$ a = \dfrac{-v_0}{\Delta t} $$
#
#
# ### Calcolo della distanza d'arresto
# La distanza di arresto può essere ottenuta tramite le leggi del moto uniformemente accelerato
#
# $$ x = x_0 + v_0\cdot(t - t_0) + \dfrac{1}{2}a\cdot(t - t_0)^2 $$
#
# Ricordiamo che i valori di $x_0, t_0$ e $v_0$ sono noti e che il valore dell'accelerazione $a$ è stato calcolato nella prima parte del problema. Per calcolare il valore della coordinata $x$ in corrispondenza della quale l'aereo si ferma  basterà sostituire il valore di $(t-t_0)$ che è dato dal testo del problema.
#
# La distanza percorsa fra il punto in cui l'aereo tocca la pista di atterraggio ed il punto in cui l'aereo di ferma è la **distanza di arresto**. Si ha quindi
#
# $$ d = x - x_0 $$
#
# cioè
#
# $$ d = v_0\cdot(t - t_0) + \dfrac{1}{2}a\cdot(t - t_0)^2 $$
#
# &nbsp;
#
# Anzichè sostituire il valore calcolato di $a$ si può utilizzare il calcolo simbolico. Considerando l'espressione dell'accelerazione $a$, segue
#
# $$ d = v_0 \Delta t + \dfrac{1}{2}\dfrac{\Delta v}{\Delta t}(\Delta t)^2 $$
#
# e poichè in questo caso si ha $\Delta v = 0 - v_0$, si ottiene
#
# $$ d = v_0 \Delta t - \dfrac{1}{2}v_0 \Delta t $$
#
# quindi
#
# $$ d = \dfrac{1}{2}v_0 \Delta t $$
#
# ### Metodo alternativo
# Considerando la relazione
#
# $$ v^2 = v_0^2 + 2 a\cdot(x - x_0) $$
#
# in questo caso si ottiene
#
# $$ x - x_0 = \dfrac{-v_0^2}{2 a} $$
#
# Il valore dell'accelerazione $a$ è noto dalla prima parte del problema e $v_0$ è un dato noto del problema, quindi con questa equazione di può calcolare la distanza di arresto $d$ che è pari ad $(x-x_0)$.
#
# Questa equazione evidenzia che
#
# - la distanza di arresto è direttamente proporzionale al quadrato della velocità iniziale
#
# - la distanza di arresto è inversamente proporzionale al modulo dell'accelerazione, che dipende dall'intensità dell'azione frenante
#
# - la quantità $d = x - x_0$ è positiva, in quanto il fattore $-v_0^2$ è negativo e l'accelerazione $a$ è negativa
#
# &nbsp;
#
# D'altra parte, utilizzando il calcolo simbolico si può scrivere
#
# $$ x - x_0 = -\dfrac{v_0^2}{2} \dfrac{\Delta t}{\Delta v} $$
#
# ovvero
#
# $$ x - x_0 = -\dfrac{v_0^2}{2} \dfrac{\Delta t}{-v_0} $$
#
# da cui infine
#
# $$ x - x_0 = \dfrac{1}{2} v_0 \Delta t $$

# %% [markdown]
# ## Calcoli con Python

# %%
vi = 234     # initial speed (km/h)
v0 = vi/3.6  # initial speed (m/s)
Dt = 2       # time lapse (s)
x0 = 0

a = - v0 / Dt             # acceleration
x = x0 + 0.5 * v0 * Dt    # final position
d = x - x0                # distance

print('\ninitial speed v0 = ', v0, '(m/s)')
print('\nacceleration a = ', a, '(m/s^2)')
print('\ndistance d = ', d, '(m)', '\n')
# Out:
# initial speed v0 =  65.0 (m/s)
#
# acceleration a =  -32.5 (m/s^2)
#
# distance d =  65.0 (m)

# %% [markdown]
# ## Get a feel of
# Calcolare il rapporto fra il valore assoluto dell'accelerazione nella fase di atterraggio ed il valore assoluto dell'accelerazione di gravità terrestre

# %%
g = 9.81
ratio = abs(a)/g
print('ratio |a|/g = ' , ratio)
# Out:
# ratio |a|/g =  3.312945973496432

# %% [markdown]
# &nbsp;
#
# # Approfondimento
# ### Rappresentazione grafica delle equazioni del moto

# %%
import numpy as np
import matplotlib.pyplot as plt

t0 = 0

print()
print('acceleration = ', a, ' (m/s^2) \n')
numpoints = 100

t = np.linspace(t0,t0 + Dt,numpoints)

v = v0 + a * (t - t0)

x = x0 + v0 * (t - t0) + 0.5 * a * (t - t0)**2

fig1 = plt.figure(figsize=(7, 13))

plt.subplot(3, 1, 1)
plt.axhline(y = a, xmin = 0.05, xmax = 0.95, color = 'green', linewidth = 3)
plt.axhline(y=0, color = 'gray', zorder = -1)
plt.axvline(x=t0, zorder = -1, linestyle = '--')
plt.axvline(x=t0+Dt, zorder = -1, linestyle = '--')
plt.xlabel('time  $t$ (s)')
plt.ylabel('$a$ (m/s$^2$)')

plt.subplot(3, 1, 2)
plt.plot(t, v, '-', color = 'red', linewidth = 2)
plt.axhline(color = 'gray', zorder = -1)
plt.axvline(color = 'gray', zorder = -1)
plt.xlabel('time  $t$ (s)')
plt.ylabel('$v$ (m/s)')

plt.subplot(3, 1, 3)
plt.plot(t, x, '-', color = 'blue', linewidth = 2)
plt.axhline(color = 'gray', zorder = -1)
plt.axhline(y = d, xmin=0.05, xmax = 0.95, color = 'orange', linestyle = '--', zorder = -1)
plt.axvline(color = 'gray', zorder = -1)
plt.xlabel('time  $t$ (s)')
plt.ylabel('$x$ (m)')
# Out:
# acceleration =  -32.5  (m/s^2)
# Text(0, 0.5, '$x$ (m)')

# %% [markdown]
# ### Velocità in funzione della posizione

# %%
fig2 = plt.figure( )

#plt.subplot(2, 1, 1)
plt.plot(x, v, '-', color = 'orange', linewidth = 3)
plt.axhline(color = 'gray', zorder = -1)
plt.axvline(color = 'gray', zorder = -1)
plt.xlabel('$x$ (m)')
plt.ylabel('$|v|$ (m/s)')
# Out:
# Text(0, 0.5, '$|v|$ (m/s)')

# %% [markdown]
# ## What we have learned
#
# *Fisica*
# * Moto con accelerazione negativa costante
# * Distanza di arresto e fattori da cui è influenzata
#
# *Python - Jupyter*
# * Inserire nel notebook un'immagine disponibile in Internet
# * Inserire nel notebook un video disponibile su YouTube
# * Costruire il grafico di una funzione
# * Costruire una figura che include più grafici
#
#
# ## References and notes
#
# ### Images
#  * Image 1 is at https://www.aviation-report.com/mediterraneo-caccia-francesi-e-americani-operano-indifferentemente-dalle-portaerei-de-gaulle-ed-eisenhower/
#
#  * Image 2 is at https://marinecue.it/portaerei-appontaggio-cavo-arresto/11260/
#
#  * Video from YouTube (https://youtu.be/KNDey1HOOVw)
#
#  * Images 3 and 4 are at (https://it.quora.com/Cosa-succede-a-un-jet-che-sorpassa-la-pista-di-atterraggio-di-una-portaerei-e-non-riesce-a-fermarsi-prima-che-questa-termini)
#     * (https://qph.fs.quoracdn.net/main-qimg-3ef93e0a73fd2f8e7919b8664bb79c25)
#     * (https://qph.fs.quoracdn.net/main-qimg-74da0bc602a1df0f69b668be189065ab)
#
#  * Image 5 is at (https://en.wikipedia.org/wiki/Modern_United_States_Navy_carrier_air_operations)
#      * (https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/FA-18_Trap.jpg/1280px-FA-18_Trap.jpg)
#
#
# &nbsp;
#
#  ## Copyright and License
#
# Apart from the photographs and the video mentioned above, all content is under Creative Common Attribution CC BY 4.0 and all code is under BSD 3-Clause License (c) 2020 Andrea Mandanici, Giuseppe Mandaglio, Giovanni Pirrotta.
